# %% [markdown]
# # Explorative data analysis of cleaned data frame

# %% [markdown]
# This notebook is meant for EDA of the dataframe we ended up with after cleaning the data from irrelevant attributes, missing values, duplicates and outliers

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('..\Yelp Dataset\merged_data.csv')
df.head()
# Out:
#                 review_id                 user_id             business_id  \
# 0  vkVSCC7xljjrAI4UGfnKEQ  bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA
# 1  vm1b1keOzwHjtGZEPPuYXA  xYciRtVZ1PW4IxSX4oJ1aw  AEx2SYEUJmTxVVB18LlCwA
# 2  jUzausdZ_ujqe_n8BlBj-g  DVOOF0Z627DyrZ4XKQbTgA  AEx2SYEUJmTxVVB18LlCwA
# 3  SXwA9KZ-Nc_hMARk_3cJ7g  5Ymfsf9fAYz-Ds_p0xawVQ  AEx2SYEUJmTxVVB18LlCwA
# 4  oCRDwF3tszAkeszSfxwthg  5JoKz3mU42Cp906KRXDwJw  AEx2SYEUJmTxVVB18LlCwA
#
#    review_stars review_date  user_review_count  user_average_stars      city  \
# 0             5  2016-05-28                  6                4.67  Montréal
# 1             5  2016-02-22                177                3.41  Montréal
# 2             5  2017-08-08                 40                3.98  Montréal
# 3             5  2013-03-29                 79                4.52  Montréal
# 4             4  2009-01-17                  3                4.00  Montréal
#
#   state  restaurant_stars  restaurant_review_count category
# 0    QC               4.0                       84   Diners
# 1    QC               4.0                       84   Diners
# 2    QC               4.0                       84   Diners
# 3    QC               4.0                       84   Diners
# 4    QC               4.0                       84   Diners

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2144848 entries, 0 to 2144847
# Data columns (total 12 columns):
# review_id                  object
# user_id                    object
# business_id                object
# review_stars               int64
# review_date                object
# user_review_count          int64
# user_average_stars         float64
# city                       object
# state                      object
# restaurant_stars           float64
# restaurant_review_count    int64
# category                   object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 196.4+ MB

# %%
# Setting float format options to show floats with three desimals
pd.set_option('display.float_format', lambda x: '%.3f' % x)

df.describe(include='all')
# Out:
#                      review_id                 user_id  \
# count                  2144848                 2144848
# unique                 2144848                  714590
# top     _xp-m-X4rWscHXinawIjEg  CxDOIDnH8gp9KXzpBHJYXw
# freq                         1                    1560
# mean                       NaN                     NaN
# std                        NaN                     NaN
# min                        NaN                     NaN
# 25%                        NaN                     NaN
# 50%                        NaN                     NaN
# 75%                        NaN                     NaN
# max                        NaN                     NaN
#
#                    business_id  review_stars review_date  user_review_count  \
# count                  2144848   2144848.000     2144848        2144848.000
# unique                   38454           nan        4465                nan
# top     4JNXUYY8wbaaDmk3BPzlWw           nan  2017-08-13                nan
# freq                      7362           nan        1963                nan
# mean                       NaN         3.689         NaN            118.490
# std                        NaN         1.364         NaN            324.025
# min                        NaN         1.000         NaN              0.000
# 25%                        NaN         3.000         NaN              9.000
# 50%                        NaN         4.000         NaN             27.000
# 75%                        NaN         5.000         NaN            100.000
# max                        NaN         5.000         NaN          11323.000
#
#         user_average_stars       city    state  restaurant_stars  \
# count          2144848.000    2144848  2144848       2144848.000
# unique                 nan        691       37               nan
# top                    nan  Las Vegas       NV               nan
# freq                   nan     600151   683342               nan
# mean                 3.720        NaN      NaN             3.693
# std                  0.730        NaN      NaN             0.606
# min                  1.000        NaN      NaN             1.000
# 25%                  3.400        NaN      NaN             3.500
# 50%                  3.790        NaN      NaN             4.000
# 75%                  4.140        NaN      NaN             4.000
# max                  5.000        NaN      NaN             5.000
#
#         restaurant_review_count category
# count               2144848.000  2144848
# unique                      nan       39
# top                         nan  Mexican
# freq                        nan   159527
# mean                    419.864      NaN
# std                     823.857      NaN
# min                       3.000      NaN
# 25%                      64.000      NaN
# 50%                     174.000      NaN
# 75%                     420.000      NaN
# max                    7361.000      NaN

# %% [markdown]
# We want to only include states with over 1000 reviews and that are located in US or Canada. Therefore we subset only those states.

# %%
# Value counts into dataframe
state_values = pd.DataFrame(df.state.value_counts())

# Filtering states with over 1000 reviews
state_values = state_values[state_values['state'] > 1000]

# Dropping BW (Germany) and EDH (Edinburgh)
state_values.drop(['BW', 'EDH'], inplace=True)

# Getting indexes
state_idx = state_values.index

# Filtering df with state_idx
df = df[df['state'].isin(state_idx)]
print(df.state.value_counts())
df.shape
# Out:
# NV    683342
# AZ    637758
# ON    309475
# NC    130851
# OH    110417
# PA    103828
# QC     73682
# WI     47477
# IL     15642
# SC      4666
# Name: state, dtype: int64
# (2117138, 12)

# %%
# Setting up seaborn for plotting
sns.set(palette="deep", font_scale=1.1)

# %% [markdown]
# ### Categorical variables

# %%
# Reviews in each state
plt.figure(figsize=(14,8))
chart = sns.countplot(data=df, x='state', order = df['state'].value_counts().index)
chart = chart.set_xticklabels(labels=df['state'].value_counts().index)

# %%
# Reviews in each city
df.city.value_counts()
# Out:
# Las Vegas                    600151
# Phoenix                      237624
# Toronto                      197568
# Scottsdale                   113132
# Charlotte                     99204
# Pittsburgh                    79727
# Henderson                     64159
# Tempe                         60535
# Montréal                      60143
# Mesa                          49144
# Chandler                      47056
# Cleveland                     40038
# Madison                       37461
# Gilbert                       35423
# Glendale                      32675
# Mississauga                   23198
# Markham                       20379
# Peoria                        15508
# North Las Vegas               13202
# Surprise                      11338
# Richmond Hill                 10903
# Champaign                     10557
# Goodyear                       9178
# Scarborough                    9017
# North York                     8724
# Avondale                       7279
# Vaughan                        6810
# Lakewood                       6486
# Concord                        6406
# Brampton                       5553
#                               ...
# Township of Concord               3
# Northbrook                        3
# Springbrook                       3
# Sainte-Rose                       3
# St-Jerome                         3
# Litchfield                        3
# Mirabel                           3
# Bois-Des-Filion                   3
# Mentor On The Lake                3
# Oka                               3
# Roxboro                           3
# Oakridges                         3
# St-Clet                           3
# Baldwin                           3
# Napierville                       3
# Cuddy                             3
# Garfield hts                      3
# Summerlin South                   3
# Saint-Basile-Le-Grand             3
# Candiac                           3
# Springfield                       3
# Laval, Ste Dorothee               3
# Maple Grove                       3
# Middleburg                        3
# Sturgeon                          3
# Linden                            3
# N Royalton                        3
# Ridgeville                        3
# Ste-Therese-de-Blainville         3
# Godmanchester                     3
# Name: city, Length: 612, dtype: int64

# %%
# Review counts of different cuisiness

plt.figure(figsize=(14,8))
chart = sns.countplot(data=df, x='category', order = df['category'].value_counts().index)
chart.set_xticklabels(labels=df['category'].value_counts().index, rotation=90)

df.category.value_counts()
# Out:
# Mexican                   158711
# American (New)            149824
# American (Traditional)    146329
# Breakfast & Brunch        128955
# Pizza                     123101
# Italian                   116552
# Sandwiches                106318
# Chinese                    99420
# Burgers                    88497
# Japanese                   79364
# Sushi Bars                 76583
# Seafood                    69694
# Steakhouses                66638
# Fast Food                  56071
# Thai                       52881
# Asian Fusion               50404
# Salad                      43991
# Barbeque                   43802
# Vietnamese                 42706
# Cafes                      36687
# Mediterranean              36420
# Indian                     31656
# French                     29688
# Diners                     27968
# Korean                     26012
# Vegetarian                 25804
# Desserts                   24560
# Chicken Wings              23812
# Greek                      20609
# Bakeries                   19308
# Canadian (New)             18660
# Delis                      17362
# Middle Eastern             15746
# Soup                       14010
# Tex-Mex                    13894
# Hot Dogs                   12148
# Latin American             11542
# Caribbean                   8930
# German                      2481
# Name: category, dtype: int64

# %%
df.shape
# Out:
# (2117138, 12)

# %%
df.to_csv('..\Yelp Dataset\clean.csv')
